# %% [markdown]
# <a href="https://colab.research.google.com/github/shhh-33/sesac-python/blob/shhh/%EB%AA%A8%EB%93%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 모듈
# 관련있는 형식이나 기능을 모아서 정의한 코드 집합
# 파이썬에서는 하나의 파이썬 파일(.py)로 정의
# -표준 모듈 : 파이썬을 설치하면 기본적으로 사용 가능한 모듈
# -외부 모듈 : 별도의 설치를 해야 사용가능한 모듈
# -사용자 정의 모듈 : 개발자가 직접 정의한 모듈

# %% [markdown]
# 진입점(entry point)
# 프로그램을 실행시켰을때 시작하는 지점
# __name__에는 진입점이 무엇인지 알 수 있다.

# %%
def print_n(s,n=1):
  for i in range(n):
    print(f"{i+1} s")

# %%
def print_list(ls):
  for i,elem in enumerate(ls):
    print(f"{i+1} : {elem}")

# %%
if __name__=="__main__": #현재 파일의 main이 진입점일때 수행하시오
    print_n("Hello",3)
    print_list([1,2,3])
# Out:
# 1 s
# 2 s
# 3 s
# 1 : 1
# 2 : 2
# 3 : 3

# %%
import sys

sys.path.append('/content/drive/MyDrive/파이썬') #파일명 편하게 접근하려고 path에 등록해서 사용
sys.path
# Out:
# ['',
#  '/content',
#  '/env/python',
#  '/usr/lib/python37.zip',
#  '/usr/lib/python3.7',
#  '/usr/lib/python3.7/lib-dynload',
#  '/usr/local/lib/python3.7/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.7/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/content/drive/MyDrive/파이썬',
#  '/content/drive/MyDrive/파이썬']

# %%
import dummy

# %%
print_n("hello",3)
# Out:
# 1s
# 2s
# 3s

# %%
dummy.print_list([1,2,3])
# Out:
# 1 : 1
# 2 : 2
# 3 : 3

# %%
from dummy import print_n

# %%
print_n("ya"),3
# Out:
# 1 s
# (None, 3)

# %%
print_list([1,2,3])
# Out:
# 1 : 1
# 2 : 2
# 3 : 3

# %%
from dummy import * #모든것의 이름을 직접 사용하겠다 다른 모듈에 같은 이름 있을때 모호할 수 있으니 권장x

# %%
print_n("ya",3)
# Out:
# 1 s
# 2 s
# 3 s

# %%
import dummy as dm
dm.print_n("ya",3)
# Out:
# 1 s
# 2 s
# 3 s

# %%
import dummy2 as d2
# Out:
# 1: Hello
# 2: Hello
# 3: Hello

# %%
d2.dprint('hello',3)
# Out:
# 1: hello
# 2: hello
# 3: hello

# %%
import math

# %%
print(f"{math.sin(math.pi):.5f}")
print(f"{math.cos(math.pi):.5f}")
print(f"{math.tan(math.pi):.5f}")
print(f"{math.ceil(math.pi):.5f}") #올림
print(f"{math.floor(math.pi):.5f}") #내림
print(f"{round(math.pi):.5f}") #반올림
# Out:
# 0.00000
# -1.00000
# -0.00000
# 4.00000
# 3.00000
# 3.00000

# %%
#모듈 이름 써주고 내가 사용할 함수

from math import sin, cos, tan

# %%
print(f"{sin(math.pi):.5f}")
print(f"{cos(math.pi):.5f}")
print(f"{tan(math.pi):.5f}")
print(f"{math.ceil(math.pi):.5f}") #올림
print(f"{math.floor(math.pi):.5f}") #내림
print(f"{round(math.pi):.5f}") #반올림
# Out:
# 0.00000
# -1.00000
# -0.00000
# 4.00000
# 3.00000
# 3.00000

# %%
import random

# %%
#random.random() : 0~1 사이의 랜덤한 값을 반환 

for i in range(100):
    print(random.random(),end=' ') 
    if i%10 ==9:
      print()
# Out:
# 0.3767187417100063 0.3975858791055742 0.47935818685518006 0.9538510429853395 0.5608911947840405 0.6479519573714551 0.19639785765232642 0.41544614639532773 0.18848458532121493 0.9160673070188707
# 0.6497952356129343 0.8807096023039483 0.555452364598433 0.5640241351661383 0.8843078885953494 0.30623730175798547 0.7122823635802277 0.2081243515471194 0.5399937193675911 0.9993208025749769
# 0.8999033500252919 0.6062209241582129 0.3229207854093227 0.7041211809674968 0.8345507734631468 0.021172720878644524 0.9791147500654299 0.47941514866171486 0.6278743792700805 0.04061675323404457
# 0.0582718138703181 0.8709309228487121 0.7190385231278399 0.3558506500042964 0.7143806148175056 0.30970047135152534 0.4581362249522922 0.9003873745430457 0.9688884621829937 0.7709922957476646
# 0.09992004475523064 0.3867701286644306 0.7502709127224124 0.2666107632433308 0.06924924831048518 0.10637660536455418 0.6739006795551999 0.6443785887454194 0.8859800917578151 0.1215327939313624
# ...

# %%
#random.randrange : 0~n-1 사이의 정수 중 랜덤한 값 반환
#uniform(s,e) :s~e 사이의 랜덤한 실수 반환
for i in range(100):
    print(f"{random.randrange(100):8.5f}",end=' ') 
    if i%10 ==9:
      print()
# Out:
# 21.00000 50.00000 69.00000 69.00000 92.00000 28.00000 35.00000 62.00000 40.00000 14.00000
# 88.00000 35.00000 12.00000 33.00000 64.00000 63.00000 89.00000 64.00000 22.00000 43.00000
# 16.00000 69.00000  5.00000 80.00000  2.00000 36.00000 71.00000 86.00000 86.00000 43.00000
# 83.00000  6.00000 41.00000 53.00000 96.00000  4.00000 16.00000 35.00000 97.00000 72.00000
# 16.00000 74.00000 83.00000 78.00000 57.00000 15.00000 19.00000 96.00000 36.00000 66.00000
# 15.00000 70.00000 35.00000  5.00000 52.00000 86.00000 93.00000 31.00000  4.00000 47.00000
#  1.00000 90.00000 38.00000 19.00000 50.00000 87.00000  4.00000 87.00000 63.00000 59.00000
# 91.00000 71.00000 64.00000 23.00000 90.00000  9.00000 50.00000 62.00000  1.00000 56.00000
# 63.00000 88.00000 58.00000 74.00000 32.00000  9.00000 14.00000 65.00000 84.00000 58.00000
# 24.00000 43.00000  2.00000 60.00000  3.00000 60.00000 19.00000 49.00000 13.00000 98.00000

# %%
ls =[1,2,3,4,5]
random.shuffle(ls)
ls
# Out:
# [5, 1, 4, 2, 3]

# %%
import time
print('a',end='')
time.sleep(1)  #의도적으로 멈추게 (초)
# Out:
# a

# %% [markdown]
# 카카오 도서검색 api 사용하기
# 쿼리 문자열 구조
# 도메인 주소 매개변수 목록

# %%
import urllib.request
url = 'https://dapi.kakao.com/v3/search/book'
target_param = "target=title"
page_param ="page=2"
query_in = input("검색 질의:")

query_param = "query="+urllib.parse.quote(query_in) #utf-8로 인코딩
query_str = url+'?'+target_param+'&'+query_param+'&'+page_param

print(query_str)

request = urllib.request.Request(query_str) #서비스 요청에 사용할 개체를 생성
request.add_header("Authorization", "KakaoAK ")#발급받은RESTAPI키 부분은 자신에 맞게 수정하세요.
response = urllib.request.urlopen(request)
res = response.read().decode('utf-8')
print(res)
# Out:
# 검색 질의:한국
# https://dapi.kakao.com/v3/search/book?target=title&query=%ED%95%9C%EA%B5%AD&page=2
# ...

# %%
import json
jres = json.loads(res)
if jres == None:
  print("json.loads 실패")
  exit(0)
for post in jres['documents']:
  print("제목:",post['title'])
  print("설명:",post['contents'])
  print("url:",post['url'])
  print("가격:",post['price'])
  print("_________________________________")
# Out:
# 제목: 공기업 NCS 통합 봉투모의고사 4회(PSAT형+모듈형)(2020)(에듀윌)
# 설명: 주요 공기업/공사ㆍ공단 NCS 출제경향을 완벽 반영하여 PSAT형 모의고사 2회, 모듈형 모의고사 2회로 구성하였다. 여기에 매 회차 모바일 OMR 채점 서비스를 제공하여 정답만 입력하면 채점에서 성적분석까지 한 번에 쫙! 이루어지도록 하였다. 또한 유형별ㆍ영역별 주요 문제풀이 무료강의를 제공하고, 모듈이론 핵심노트까지 수록하여 2020년 공기업/공사ㆍ공단 필기시험을 완벽하게 준비할 수 있도록 하였다. 추가로 SPECIAL GUIDE를 제공하여
# url: https://search.daum.net/search?w=bookpage&bookId=5210247&q=%EA%B3%B5%EA%B8%B0%EC%97%85+NCS+%ED%86%B5%ED%95%A9+%EB%B4%89%ED%88%AC%EB%AA%A8%EC%9D%98%EA%B3%A0%EC%82%AC+4%ED%9A%8C%28PSAT%ED%98%95%2B%EB%AA%A8%EB%93%88%ED%98%95%29%282020%29%28%EC%97%90%EB%93%80%EC%9C%8C%29
# 가격: 14000
# _________________________________
# 제목: 한국을 빛낸 100명의 위인들(설민석 쌤과 함께 부르는)(사운드북)
# 설명: 한국사에 대한 관심을 키우세요! 노래를 따라 부르면 한국사에 대한 호기심이 쑥쑥 자라나요! 한국사 대중화를 위해 다양한 저술 활동과 방송 활동을 하고 있는 저자 설민석이 이번에는 유아, 어린이를 위한 한국사 사운드북을 펴냈습니다. ‘한국을 빛낸 100명의 위인들’ 노래를 따라 부르며 위대한 업적을 남긴 위인들의 이름을 기억하고, 이후 자연스럽게 한국사에 대한 관심으로 이어지도록 만들었습니다.  단순하게 노래만 듣는 사운드북이 아니라, 아이가 좀 더 자랐을 때
# ...

# %% [markdown]
# 네이버 도서검색 api 사용하기

# %%
import urllib.request
url = 'https://openapi.naver.com/v1/search/book.xml'
query_in = input("검색 질의:")
query_param = "query="+urllib.parse.quote(query_in) #utf-8로 인코딩
query_str = url+'?'+query_param

print(query_str)

request = urllib.request.Request(query_str) #서비스 요청에 사용할 개체를 생성
request.add_header('X-Naver-Client-Id','')
request.add_header('X-Naver-Client-Secret','')
response = urllib.request.urlopen(request)
res = response.read().decode('utf-8')
print(res)
# Out:
# 검색 질의:대박
# https://openapi.naver.com/v1/search/book.xml?query=%EB%8C%80%EB%B0%95
# ...

# %%
from bs4 import BeautifulSoup
xmlsoup = BeautifulSoup(res,'html.parser')
items = xmlsoup.find_all('item')
for item in items:
  print("제목:",item.title.get_text())
  print("설명:",item.description.get_text())
  print("가격:",item.price.get_text())
# Out:
# 제목: EBS 강의노트 수능개념 정승익의 개념잡은 <b>대박</b>노트 All in One (2023 수능대비,2022)
# 설명: 이 책은 정승익의 2023학년도 수능 대비 개념편 영어 강의노트에 대해 다룬 도서입니다. 기초적이고 전반적인 내용을 확인할 수 있도록 구성했습니다.
# 가격: 10000
# 제목: EBS 정승익의 수능 개념 잡는 <b>대박</b>구문 (2022)
# 설명: 정승익 선생님과 기출구문으로 수능 영어 대비정승익 선생님 직접 집필·강의“정승익의 수능 개념 잡는 <b>대박</b>구문”수/박/구/문으로 중학교 영어에서 고등학교 영어로 수준 업그레이드!수능 독해에 필요한 문장 해석 능력을 키우는 800개의 기출구문 STEP 1 #CODE_수능 영어의 모든 구문을...
# 가격: 15000
# 제목: EBSi 강의노트 수능개념 영어 정승익의 개념잡는 <b>대박</b>노트 (2021년) (2022 수능대비 강의노트)
# 설명: - 독자대상 : 고등학생
# - 구성 : 이론 + 문제
# - 특징 :
# ① 수능대비의 시작 중요 핵심부터 최신 경향까지
# ② 수능 연계 시리즈로 이어지는 EBS 수능 커리큘럼
# ③ 다년간의 학교 강의, 내신 시험 출제 전문가들에게 직접 듣는 2022 수능 개념
# 가격: 7500
# 제목: 내 생애 짜릿한 <b>대박</b> 상가 투자법
# 설명: 아는 만큼 돈이 된다!
# 나만 알고 싶은 상가 투자 비법부동산으로 돈을 벌고 싶고, 상가 투자로 성공하고 싶은데 어떻게 해야 돈이 되는 상가에 투자할 수 있을까? 10여 년 넘게 상가 투자를 해오며, 만 명에 가까운 회원을 보유한 네이버 카페 ‘길목부동산연구소’를 운영하는 지은이 길목은 자신 있게 ‘돈 되는...
# 가격: 18000
# 제목: <b>대박</b>나는 디지털 마케팅 (디지털 마케팅의 전략 전술)
# ...

# %%
import urllib.request
url = 'http://apis.data.go.kr/1390804/NihhsFuriAirInfo/selectPuriAirPlantView'
skey_param = "servicekey="
id_param ="idx=82"

query_str = url+'?'+skey_param+'&'+id_param  

"""
REST(URI) : http://apis.data.go.kr/1390804/NihhsFuriAirInfo/selectPuriAirPlantView?servicekey=서비스키&idx=82 니까 위처럼 쓴다.
"""

print(query_str)

request = urllib.request.Request(query_str) #서비스 요청에 사용할 개체를 생성

response = urllib.request.urlopen(request)
res = response.read().decode('utf-8')
print(res)
# Out:
# http://apis.data.go.kr/1390804/NihhsFuriAirInfo/selectPuriAirPlantView?servicekey=%2F33q%2FK5oBqwjoP1n%2FY0EcpshnUhp5EcEujh2%2BCwA0LC60wTT78oMh7Heus0Wv1Dmyzjr2%2BPZTfqlhf2CoQDWFQ%3D%3D&idx=82
# <?xml version="1.0" encoding="utf-8"?>
#
# ...

# %%
from bs4 import BeautifulSoup
xmlsoup = BeautifulSoup(res,'html.parser')
print(xmlsoup)
print("제목:",xmlsoup.title.get_text())
#items = xmlsoup.find_all('resultTitle')
#for item in items:
  #print("제목:",resultTitle.title.get_text())
   #print(item)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# ...

# %%
import urllib.request
url = 'http://apis.data.go.kr/B553077/api/open/sdsc2/storeZoneOne'
key ="9174"
skey_param = "serviceKey="


query_str = url+'?'+key+'&'+skey_param


print(query_str)

request = urllib.request.Request(query_str) #서비스 요청에 사용할 개체를 생성

response = urllib.request.urlopen(request)
res = response.read().decode('utf-8')
print(res)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 				<coordNum>80</coordNum>
# ...

# %%
from bs4 import BeautifulSoup
xmlsoup = BeautifulSoup(res,'html.parser')
items = xmlsoup.find_all('item')
for item in items:
  #print(item)
  print("제목:", item.maintrarnm.get_text())
# Out:
# 제목: 강서동
# 제목: 공구상가
# 제목: 청주고속버스터미널
# 제목: 청주산업단지
# 제목: 홈플러스
# 제목: 흥덕구청
# 제목: 농수산물시장
# 제목: 광혜원면
# 제목: 진천읍
# 제목: 종로5가역_3
# 제목: 종로5가역_4
# 제목: 종로구청
# 제목: 종묘앞_1
# 제목: 종묘앞_2
# 제목: 종묘앞_3
# 제목: 혜화역 대학로_1
# 제목: 혜화역 대학로_2
# 제목: 혜화역 대학로_3
# 제목: 서대문역_1
# 제목: 경복궁역_1
# 제목: 경복궁역_2
# 제목: 광화문역_1
# 제목: 광화문역_2
# 제목: 동대문시장_1
# 제목: 동대문역_1
# 제목: 동대문역_2
# 제목: 안국역
# 제목: 인사동
# 제목: 종각역
# 제목: 종각역 젊음의거리
# 제목: 종로3가역_1
# 제목: 종로3가역_2
# 제목: 종로3가역_3
# 제목: 종로5가역_1
# 제목: 종로5가역_2
# 제목: 숙대입구역
# 제목: 신용산역
# 제목: 용산 전자상가_1
# 제목: 용산 전자상가_2
# 제목: 용산 전자상가_3
# 제목: 용산 전자상가_4
# 제목: 용산 전자상가_5
# 제목: 용산구청
# 제목: 이태원역
# 제목: 한남오거리
# 제목: 강남역_1
# 제목: 강남역_2
# 제목: 고속터미널역
# 제목: 교대역_1
# 제목: 교대역_2
# 제목: 교대역_3
# 제목: 교대역_4
# 제목: 남부터미널역_1
# 제목: 남부터미널역_2
# 제목: 남부터미널역_3
# 제목: 방배동카페골목
# 제목: 방배역
# 제목: 뱅뱅사거리_3
# 제목: 사당역
# 제목: 서초역
# 제목: 양재 화물트럭터미널앞
# 제목: 양재동 꽃시장
# 제목: 양재역_1
# 제목: 양재역_3
# 제목: 서래마을
# 제목: 신사역_1
# 제목: 논현역_3
# 제목: 논현역_4
# 제목: 포이사거리_2
# 제목: 가리봉시장(구로디지털오거리)
# 제목: 구로중앙유통단지
# 제목: 대림역
# 제목: 신도림역
# 제목: 오류동
# 제목: 개봉동 현대아파트
# 제목: 구로기계공구상_1
# ...
